# %%
import pandas as pd

data = {
    "Name": ["Amit", "Sneha", "Rahul", "Pooja", "Karan"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [50000, 40000, 60000, 45000, 42000]
}

df = pd.DataFrame(data)
df
# Out:
#     Name Department  Salary
# 0   Amit         IT   50000
# 1  Sneha         HR   40000
# 2  Rahul         IT   60000
# 3  Pooja    Finance   45000
# 4  Karan         HR   42000

# %%
df["Salary"].mean()
# Out:
# np.float64(47400.0)

# %%
df.loc[df["Salary"].idxmax()]
# Out:
# Name          Rahul
# Department       IT
# Salary        60000
# Name: 2, dtype: object

# %%
df.loc[df["Salary"].idxmin()]
# Out:
# Name          Sneha
# Department       HR
# Salary        40000
# Name: 1, dtype: object

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    45000.0
# HR         41000.0
# IT         55000.0
# Name: Salary, dtype: float64

# %%
import matplotlib.pyplot as plt

dept_salary = df.groupby("Department")["Salary"].mean()

dept_salary.plot(kind="bar")

plt.title("Department Wise Average Salary")
plt.xlabel("Department")
plt.ylabel("Salary")

plt.show()
